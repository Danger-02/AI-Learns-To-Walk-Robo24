# %% [markdown]
# ## **ROBOTICS 24 - AI LEARNS TO WALK :**
# ### **In this section, the Reinforcement Model is actually trained and evaluated.**
# ---

# %% [markdown]
# ### **USING REINFORCEMENT LEARNING ON - ANTBULLET-V0**

# %%
import gym, time, pybullet, pybullet_envs
import numpy as np
import torch.nn as nn

from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from tqdm import tqdm

env = gym.make("AntBulletEnv-v0")

policy_kwargs = dict(activation_fn=nn.ReLU,net_arch=[dict(pi=[128, 128], vf=[128, 128])])
model = PPO("MlpPolicy", env, policy_kwargs=policy_kwargs, verbose=1)

max_average_reward = -np.inf
num_episodes = 100

print("Starting Training...")
for i in tqdm(range(1, num_episodes + 1)):
    print(f"\nTraining Episode {i} started.")

    model.learn(total_timesteps=10000)

    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
    print(f"Episode: {i}, Mean Reward: {mean_reward:.2f}, Std Reward: {std_reward:.2f}, Total Timesteps: {model.num_timesteps}, Time: {time.asctime(time.localtime(time.time()))}")

    if i % 100 == 0:
        model.save(f"AntBulletEnv-v0_PPO_{i}")
        print(f"Model saved at Episode {i}.")
    
    if mean_reward > max_average_reward:
        max_average_reward = mean_reward
        print(f"New best model with Mean Reward: {mean_reward:.2f}. Saving model.")
        model.save("AntBulletEnv-v0_PPO_Best")

print("Training completed.")
env.close()
pybullet.disconnect()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# e:\Anaconda\envs\Reinforcement_Learning\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# e:\Anaconda\envs\Reinforcement_Learning\lib\site-packages\stable_baselines3\common\policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# e:\Anaconda\envs\Reinforcement_Learning\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# Starting Training...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Training Episode 1 started.
# -----------------------------
# | time/              |      |
# |    fps             | 542  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 460         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009790984 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 0.0223      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.599       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.993       |
# |    value_loss           | 7           |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.004379088 |
# |    clip_fraction        | 0.0799      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 0.0366      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.21        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00837    |
# |    std                  | 0.998       |
# |    value_loss           | 2.83        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 436         |
# |    iterations           | 4           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008659396 |
# |    clip_fraction        | 0.0896      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 0.13        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.696       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00804    |
# |    std                  | 0.999       |
# |    value_loss           | 2.25        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 3.6e+03     |
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 5           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008501503 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 0.111       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.662       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.998       |
# |    value_loss           | 1.61        |
# -----------------------------------------
# e:\Anaconda\envs\Reinforcement_Learning\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# e:\Anaconda\envs\Reinforcement_Learning\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
#   1%|          | 1/100 [00:25<42:10, 25.56s/it]
# Episode: 1, Mean Reward: 10.62, Std Reward: 4.02, Total Timesteps: 10240, Time: Tue Jan 28 02:28:45 2025
# New best model with Mean Reward: 10.62. Saving model.
#
# Training Episode 2 started.
# -----------------------------
# | time/              |      |
# |    fps             | 534  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 455         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007976798 |
# |    clip_fraction        | 0.0945      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | -1.12       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.761       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.993       |
# |    value_loss           | 2.43        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 436         |
# |    iterations           | 3           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006387887 |
# |    clip_fraction        | 0.083       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 0.0438      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.682       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0036     |
# |    std                  | 0.992       |
# |    value_loss           | 1.64        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 424         |
# |    iterations           | 4           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010386189 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.3       |
# |    explained_variance   | 0.0628      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.769       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00646    |
# |    std                  | 0.99        |
# |    value_loss           | 1.52        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+04        |
# |    ep_rew_mean          | 3.02e+03     |
# | time/                   |              |
# |    fps                  | 420          |
# |    iterations           | 5            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0124962395 |
# |    clip_fraction        | 0.145        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11.3        |
# |    explained_variance   | 0.111        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.616        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.0135      |
# |    std                  | 0.989        |
# |    value_loss           | 1.14         |
# ------------------------------------------
#   2%|▏         | 2/100 [00:51<42:16, 25.88s/it]
# Episode: 2, Mean Reward: 17.78, Std Reward: 4.11, Total Timesteps: 10240, Time: Tue Jan 28 02:29:11 2025
# New best model with Mean Reward: 17.78. Saving model.
#
# Training Episode 3 started.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 266      |
# |    ep_rew_mean     | 127      |
# | time/              |          |
# |    fps             | 546      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 266         |
# |    ep_rew_mean          | 127         |
# | time/                   |             |
# |    fps                  | 478         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010884056 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | -0.332      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.59        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0118     |
# |    std                  | 0.985       |
# |    value_loss           | 9.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 266         |
# |    ep_rew_mean          | 127         |
# | time/                   |             |
# |    fps                  | 454         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010017146 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | -0.0505     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.402       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.987       |
# |    value_loss           | 0.938       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 266         |
# |    ep_rew_mean          | 127         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 4           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011299394 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | 0.141       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.28        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0132     |
# |    std                  | 0.986       |
# |    value_loss           | 0.694       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 266         |
# |    ep_rew_mean          | 127         |
# | time/                   |             |
# |    fps                  | 437         |
# |    iterations           | 5           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011712529 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.2       |
# |    explained_variance   | 0.131       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.132       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.984       |
# |    value_loss           | 0.478       |
# -----------------------------------------
#   3%|▎         | 3/100 [01:17<41:58, 25.97s/it]
# Episode: 3, Mean Reward: 78.75, Std Reward: 44.83, Total Timesteps: 10240, Time: Tue Jan 28 02:29:37 2025
# New best model with Mean Reward: 78.75. Saving model.
#
# Training Episode 4 started.
# -----------------------------
# | time/              |      |
# |    fps             | 530  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011789501 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0.387       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.301       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.02       |
# |    std                  | 0.971       |
# |    value_loss           | 0.816       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 450         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010898076 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0.264       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.225       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 0.968       |
# |    value_loss           | 0.528       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 442         |
# |    iterations           | 4           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013499333 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -11.1       |
# |    explained_variance   | 0.439       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.271       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0198     |
# |    std                  | 0.96        |
# |    value_loss           | 0.798       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+04      |
# |    ep_rew_mean          | 5.24e+03   |
# | time/                   |            |
# |    fps                  | 430        |
# |    iterations           | 5          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01132551 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -11        |
# |    explained_variance   | 0.482      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.219      |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0165    |
# |    std                  | 0.951      |
# |    value_loss           | 0.704      |
# ----------------------------------------
#   4%|▍         | 4/100 [04:02<2:08:58, 80.61s/it]
# Episode: 4, Mean Reward: 2723.15, Std Reward: 372.14, Total Timesteps: 10240, Time: Tue Jan 28 02:32:21 2025
# New best model with Mean Reward: 2723.15. Saving model.
#
# Training Episode 5 started.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 620      |
# |    ep_rew_mean     | 317      |
# | time/              |          |
# |    fps             | 552      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 620         |
# |    ep_rew_mean          | 317         |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012265472 |
# |    clip_fraction        | 0.0941      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | 0.000785    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.16        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0154     |
# |    std                  | 0.942       |
# |    value_loss           | 13.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 620         |
# |    ep_rew_mean          | 317         |
# | time/                   |             |
# |    fps                  | 459         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010859972 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.9       |
# |    explained_variance   | -0.0099     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.613       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0178     |
# |    std                  | 0.941       |
# |    value_loss           | 1.65        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 620         |
# |    ep_rew_mean          | 317         |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 4           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011109231 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | 0.343       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.262       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.933       |
# |    value_loss           | 0.781       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 620         |
# |    ep_rew_mean          | 317         |
# | time/                   |             |
# |    fps                  | 440         |
# |    iterations           | 5           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010999948 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.8       |
# |    explained_variance   | 0.717       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.29        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0149     |
# |    std                  | 0.927       |
# |    value_loss           | 0.668       |
# -----------------------------------------
#   5%|▌         | 5/100 [06:43<2:53:54, 109.84s/it]
# Episode: 5, Mean Reward: 4846.30, Std Reward: 1397.03, Total Timesteps: 10240, Time: Tue Jan 28 02:35:03 2025
# New best model with Mean Reward: 4846.30. Saving model.
#
# Training Episode 6 started.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 707      |
# |    ep_rew_mean     | 343      |
# | time/              |          |
# |    fps             | 514      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 707         |
# |    ep_rew_mean          | 343         |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012139073 |
# |    clip_fraction        | 0.0975      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.7       |
# |    explained_variance   | 0.121       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.7        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0149     |
# |    std                  | 0.917       |
# |    value_loss           | 24.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 707         |
# |    ep_rew_mean          | 343         |
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 3           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016167052 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | 0.444       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.344       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0174     |
# |    std                  | 0.917       |
# |    value_loss           | 0.847       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 707         |
# |    ep_rew_mean          | 343         |
# | time/                   |             |
# |    fps                  | 322         |
# |    iterations           | 4           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.014092647 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | 0.242       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.369       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.021      |
# |    std                  | 0.911       |
# |    value_loss           | 1.22        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 707          |
# |    ep_rew_mean          | 343          |
# | time/                   |              |
# |    fps                  | 310          |
# |    iterations           | 5            |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0143395495 |
# |    clip_fraction        | 0.195        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -10.6        |
# |    explained_variance   | 0.164        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.5          |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0197      |
# |    std                  | 0.909        |
# |    value_loss           | 1.16         |
# ------------------------------------------
#   6%|▌         | 6/100 [09:38<3:26:54, 132.06s/it]
# Episode: 6, Mean Reward: 5974.41, Std Reward: 758.80, Total Timesteps: 10240, Time: Tue Jan 28 02:37:58 2025
# New best model with Mean Reward: 5974.41. Saving model.
#
# Training Episode 7 started.
# -----------------------------
# | time/              |      |
# |    fps             | 529  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012667354 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | 0.825       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.288       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0252     |
# |    std                  | 0.909       |
# |    value_loss           | 1.17        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 449         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014743643 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.6       |
# |    explained_variance   | 0.818       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.324       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0271     |
# |    std                  | 0.907       |
# |    value_loss           | 0.9         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 436         |
# |    iterations           | 4           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.019768253 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.5       |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0914      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0179     |
# |    std                  | 0.895       |
# |    value_loss           | 0.489       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+04      |
# |    ep_rew_mean          | 5.79e+03   |
# | time/                   |            |
# |    fps                  | 430        |
# |    iterations           | 5          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01951411 |
# |    clip_fraction        | 0.191      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.5      |
# |    explained_variance   | 0.904      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.246      |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0222    |
# |    std                  | 0.9        |
# |    value_loss           | 1.25       |
# ----------------------------------------
#   7%|▋         | 7/100 [12:25<3:42:05, 143.28s/it]
# Episode: 7, Mean Reward: 5131.49, Std Reward: 1111.45, Total Timesteps: 10240, Time: Tue Jan 28 02:40:45 2025
#
# Training Episode 8 started.
# -----------------------------
# | time/              |      |
# |    fps             | 533  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 460         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011537492 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.5       |
# |    explained_variance   | 0.113       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.63        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.895       |
# |    value_loss           | 1.49        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.025180118 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.5       |
# |    explained_variance   | 0.171       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.768       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00914    |
# |    std                  | 0.897       |
# |    value_loss           | 1.49        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 437         |
# |    iterations           | 4           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012141413 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.4       |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.503       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0192     |
# |    std                  | 0.891       |
# |    value_loss           | 1.08        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 5.78e+03    |
# | time/                   |             |
# |    fps                  | 432         |
# |    iterations           | 5           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.013282632 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.4       |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.555       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0202     |
# |    std                  | 0.886       |
# |    value_loss           | 1.15        |
# -----------------------------------------
#   8%|▊         | 8/100 [15:05<3:47:55, 148.64s/it]
# Episode: 8, Mean Reward: 3599.73, Std Reward: 625.96, Total Timesteps: 10240, Time: Tue Jan 28 02:43:25 2025
#
# Training Episode 9 started.
# -----------------------------
# | time/              |      |
# |    fps             | 546  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 481         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013354063 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.3       |
# |    explained_variance   | 0.342       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.404       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0259     |
# |    std                  | 0.879       |
# |    value_loss           | 1.33        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016454179 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 0.263       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.108       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.868       |
# |    value_loss           | 0.434       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 462         |
# |    iterations           | 4           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015833683 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 0.702       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.134       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 0.867       |
# |    value_loss           | 0.368       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 5.72e+03    |
# | time/                   |             |
# |    fps                  | 455         |
# |    iterations           | 5           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.017644307 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.2       |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.353       |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0242     |
# |    std                  | 0.863       |
# |    value_loss           | 0.759       |
# -----------------------------------------
#   9%|▉         | 9/100 [17:39<3:48:11, 150.46s/it]
# Episode: 9, Mean Reward: 4549.70, Std Reward: 785.58, Total Timesteps: 10240, Time: Tue Jan 28 02:45:59 2025
#
# Training Episode 10 started.
# -----------------------------
# | time/              |      |
# |    fps             | 532  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 467        |
# |    iterations           | 2          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01260944 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.1      |
# |    explained_variance   | 0.608      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.211      |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0229    |
# |    std                  | 0.853      |
# |    value_loss           | 0.812      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 447         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014327014 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.1       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.125       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 0.856       |
# |    value_loss           | 0.447       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 443        |
# |    iterations           | 4          |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01517689 |
# |    clip_fraction        | 0.219      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -10.1      |
# |    explained_variance   | 0.596      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.269      |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0163    |
# |    std                  | 0.854      |
# |    value_loss           | 0.794      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 5.67e+03    |
# | time/                   |             |
# |    fps                  | 440         |
# |    iterations           | 5           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.017226882 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.1       |
# |    explained_variance   | 0.131       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.675       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0237     |
# |    std                  | 0.855       |
# |    value_loss           | 2.89        |
# -----------------------------------------
#  10%|█         | 10/100 [20:20<3:50:09, 153.44s/it]
# Episode: 10, Mean Reward: 6185.36, Std Reward: 590.56, Total Timesteps: 10240, Time: Tue Jan 28 02:48:39 2025
# New best model with Mean Reward: 6185.36. Saving model.
#
# Training Episode 11 started.
# -----------------------------
# | time/              |      |
# |    fps             | 571  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 494         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.019123645 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -10.1       |
# |    explained_variance   | 0.463       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.259       |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0238     |
# |    std                  | 0.851       |
# |    value_loss           | 0.829       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 460         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.017582968 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.99       |
# |    explained_variance   | 0.663       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.103       |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.02       |
# |    std                  | 0.841       |
# |    value_loss           | 0.434       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 4           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.014470914 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.93       |
# |    explained_variance   | 0.461       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.207       |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0206     |
# |    std                  | 0.837       |
# |    value_loss           | 0.817       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 5.91e+03    |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 5           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016332258 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.91       |
# |    explained_variance   | 0.183       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.353       |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0199     |
# |    std                  | 0.836       |
# |    value_loss           | 0.874       |
# -----------------------------------------
#  11%|█         | 11/100 [22:59<3:50:29, 155.39s/it]
# Episode: 11, Mean Reward: 4559.98, Std Reward: 884.98, Total Timesteps: 10240, Time: Tue Jan 28 02:51:19 2025
#
# Training Episode 12 started.
# -----------------------------
# | time/              |      |
# |    fps             | 542  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.017196454 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.88       |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.296       |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.021      |
# |    std                  | 0.832       |
# |    value_loss           | 0.658       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 446         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016051836 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.83       |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.154       |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.0164     |
# |    std                  | 0.826       |
# |    value_loss           | 0.427       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 432         |
# |    iterations           | 4           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.014562098 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -9.77       |
# |    explained_variance   | 0.807       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.385       |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0255     |
# |    std                  | 0.819       |
# |    value_loss           | 1.37        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+04       |
# |    ep_rew_mean          | 6.06e+03    |
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 5           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# ...
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+04      |
# |    ep_rew_mean          | 2.54e+04   |
# | time/                   |            |
# |    fps                  | 363        |
# |    iterations           | 5          |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.14276274 |
# |    clip_fraction        | 0.473      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0646     |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.9       |
# |    n_updates            | 4790       |
# |    policy_gradient_loss | 0.00666    |
# |    std                  | 0.244      |
# |    value_loss           | 17.5       |
# ----------------------------------------
#  96%|█████████▌| 96/100 [21:18:33<12:35, 188.83s/it]
# Episode: 96, Mean Reward: 18758.76, Std Reward: 8943.69, Total Timesteps: 10240, Time: Tue Jan 28 23:46:52 2025
#
# Training Episode 97 started.
# -----------------------------
# | time/              |      |
# |    fps             | 556  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 476        |
# |    iterations           | 2          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.09111738 |
# |    clip_fraction        | 0.426      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0957     |
# |    explained_variance   | 0.957      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.74       |
# |    n_updates            | 4810       |
# |    policy_gradient_loss | -0.0311    |
# |    std                  | 0.243      |
# |    value_loss           | 16.2       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 452        |
# |    iterations           | 3          |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.14361444 |
# |    clip_fraction        | 0.684      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0976     |
# |    explained_variance   | 0.593      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.21       |
# |    n_updates            | 4820       |
# |    policy_gradient_loss | 0.00447    |
# |    std                  | 0.243      |
# |    value_loss           | 4.6        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 424        |
# |    iterations           | 4          |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.13143633 |
# |    clip_fraction        | 0.576      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0845     |
# |    explained_variance   | 0.695      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.05       |
# |    n_updates            | 4830       |
# |    policy_gradient_loss | -0.02      |
# |    std                  | 0.244      |
# |    value_loss           | 5.63       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+04      |
# |    ep_rew_mean          | 2.51e+04   |
# | time/                   |            |
# |    fps                  | 422        |
# |    iterations           | 5          |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.07599573 |
# |    clip_fraction        | 0.531      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0693     |
# |    explained_variance   | 0.814      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.19       |
# |    n_updates            | 4840       |
# |    policy_gradient_loss | -0.0325    |
# |    std                  | 0.244      |
# |    value_loss           | 9.55       |
# ----------------------------------------
#  97%|█████████▋| 97/100 [21:21:10<08:58, 179.36s/it]
# Episode: 97, Mean Reward: 20556.61, Std Reward: 9425.71, Total Timesteps: 10240, Time: Tue Jan 28 23:49:30 2025
#
# Training Episode 98 started.
# -----------------------------
# | time/              |      |
# |    fps             | 564  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 491       |
# |    iterations           | 2         |
# |    time_elapsed         | 8         |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 0.1406777 |
# |    clip_fraction        | 0.511     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0.101     |
# |    explained_variance   | 0.987     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.41      |
# |    n_updates            | 4860      |
# |    policy_gradient_loss | -0.0339   |
# |    std                  | 0.242     |
# |    value_loss           | 8.05      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 462        |
# |    iterations           | 3          |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.12738368 |
# |    clip_fraction        | 0.606      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.167      |
# |    explained_variance   | 0.567      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.55       |
# |    n_updates            | 4870       |
# |    policy_gradient_loss | -0.0136    |
# |    std                  | 0.24       |
# |    value_loss           | 5.18       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 456        |
# |    iterations           | 4          |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.18245724 |
# |    clip_fraction        | 0.625      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.195      |
# |    explained_variance   | 0.86       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.05       |
# |    n_updates            | 4880       |
# |    policy_gradient_loss | -0.00509   |
# |    std                  | 0.24       |
# |    value_loss           | 4.32       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+04      |
# |    ep_rew_mean          | 2.6e+04    |
# | time/                   |            |
# |    fps                  | 447        |
# |    iterations           | 5          |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.14817178 |
# |    clip_fraction        | 0.639      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.174      |
# |    explained_variance   | 0.686      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.24       |
# |    n_updates            | 4890       |
# |    policy_gradient_loss | -0.000207  |
# |    std                  | 0.241      |
# |    value_loss           | 2.62       |
# ----------------------------------------
#  98%|█████████▊| 98/100 [21:23:48<05:46, 173.05s/it]
# Episode: 98, Mean Reward: 22455.14, Std Reward: 7610.76, Total Timesteps: 10240, Time: Tue Jan 28 23:52:08 2025
#
# Training Episode 99 started.
# -----------------------------
# | time/              |      |
# |    fps             | 557  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 463        |
# |    iterations           | 2          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.08963385 |
# |    clip_fraction        | 0.391      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.188      |
# |    explained_variance   | 0.977      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.61       |
# |    n_updates            | 4910       |
# |    policy_gradient_loss | -0.047     |
# |    std                  | 0.24       |
# |    value_loss           | 16.3       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 444        |
# |    iterations           | 3          |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.09178452 |
# |    clip_fraction        | 0.539      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.226      |
# |    explained_variance   | 0.807      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.45       |
# |    n_updates            | 4920       |
# |    policy_gradient_loss | -0.0239    |
# |    std                  | 0.239      |
# |    value_loss           | 9.7        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 437         |
# |    iterations           | 4           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.111531146 |
# |    clip_fraction        | 0.609       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.28        |
# |    explained_variance   | 0.753       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.5         |
# |    n_updates            | 4930        |
# |    policy_gradient_loss | -0.0168     |
# |    std                  | 0.237       |
# |    value_loss           | 7.16        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+04      |
# |    ep_rew_mean          | 2.64e+04   |
# | time/                   |            |
# |    fps                  | 437        |
# |    iterations           | 5          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.13325503 |
# |    clip_fraction        | 0.65       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.294      |
# |    explained_variance   | 0.704      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.18       |
# |    n_updates            | 4940       |
# |    policy_gradient_loss | -0.00988   |
# |    std                  | 0.237      |
# |    value_loss           | 4.08       |
# ----------------------------------------
#  99%|█████████▉| 99/100 [21:26:29<02:49, 169.33s/it]
# Episode: 99, Mean Reward: 22837.91, Std Reward: 7830.82, Total Timesteps: 10240, Time: Tue Jan 28 23:54:49 2025
#
# Training Episode 100 started.
# -----------------------------
# | time/              |      |
# |    fps             | 534  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 480        |
# |    iterations           | 2          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.13267602 |
# |    clip_fraction        | 0.566      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.322      |
# |    explained_variance   | 0.996      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.37       |
# |    n_updates            | 4960       |
# |    policy_gradient_loss | -0.0395    |
# |    std                  | 0.236      |
# |    value_loss           | 4.74       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 404        |
# |    iterations           | 3          |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.17215133 |
# |    clip_fraction        | 0.625      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.316      |
# |    explained_variance   | 0.754      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.38       |
# |    n_updates            | 4970       |
# |    policy_gradient_loss | -0.00664   |
# |    std                  | 0.237      |
# |    value_loss           | 4.65       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 4          |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.05021271 |
# |    clip_fraction        | 0.463      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.3        |
# |    explained_variance   | 0.883      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.94       |
# |    n_updates            | 4980       |
# |    policy_gradient_loss | -0.0295    |
# |    std                  | 0.237      |
# |    value_loss           | 35.6       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+04      |
# |    ep_rew_mean          | 2.64e+04   |
# | time/                   |            |
# |    fps                  | 362        |
# |    iterations           | 5          |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.12569089 |
# |    clip_fraction        | 0.567      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.314      |
# |    explained_variance   | 0.516      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.03       |
# |    n_updates            | 4990       |
# |    policy_gradient_loss | -0.0189    |
# |    std                  | 0.237      |
# |    value_loss           | 9.27       |
# ----------------------------------------
# 100%|██████████| 100/100 [21:29:04<00:00, 773.44s/it]
# Episode: 100, Mean Reward: 20909.02, Std Reward: 7116.64, Total Timesteps: 10240, Time: Tue Jan 28 23:57:24 2025
# Model saved at Episode 100.
# Training completed.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[12], line 39
#      37 print("Training completed.")
#      38 env.close()
# ---> 39 pybullet.disconnect()
#
# error: Not connected to physics server.
